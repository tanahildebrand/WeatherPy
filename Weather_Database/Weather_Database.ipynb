# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 760

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "City Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | bonthe
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | abu kamal
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | ahipara
# Processing Record 11 of Set 1 | ambanja
# Processing Record 12 of Set 1 | prainha
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bobonong
# City not found. Skipping...
# Processing Record 17 of Set 1 | svetlyy
# Processing Record 18 of Set 1 | port lavaca
# Processing Record 19 of Set 1 | vila franca do campo
# Processing Record 20 of Set 1 | shush
# Processing Record 21 of Set 1 | oudtshoorn
# Processing Record 22 of Set 1 | mahibadhoo
# Processing Record 23 of Set 1 | half moon bay
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | maniitsoq
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | avera
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | onda
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | togur
# Processing Record 36 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | amalapuram
# Processing Record 39 of Set 1 | stornoway
# Processing Record 40 of Set 1 | linqiong
# Processing Record 41 of Set 1 | wuxue
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | leningradskiy
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | kyra
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | port lincoln
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | filingue
# Processing Record 6 of Set 2 | vila velha
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | raudeberg
# Processing Record 9 of Set 2 | japura
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | naze
# Processing Record 12 of Set 2 | erzin
# Processing Record 13 of Set 2 | morondava
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | ihosy
# Processing Record 17 of Set 2 | milkovo
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | mafeteng
# Processing Record 22 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 2 | roseburg
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | hamilton
# Processing Record 26 of Set 2 | beyneu
# Processing Record 27 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | kenai
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | komsomolskiy
# Processing Record 32 of Set 2 | lavrentiya
# Processing Record 33 of Set 2 | sao joao da barra
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | ibra
# Processing Record 36 of Set 2 | lethem
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | marawi
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | sayansk
# Processing Record 42 of Set 2 | vylkove
# Processing Record 43 of Set 2 | platanos
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | kirkwall
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | zhuhai
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | baru
# Processing Record 50 of Set 2 | bahia honda
# Processing Record 1 of Set 3 | samarai
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | itarema
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | atherton
# Processing Record 9 of Set 3 | pafos
# Processing Record 10 of Set 3 | hays
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | longkou
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | longview
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | severnyy
# Processing Record 17 of Set 3 | arecibo
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | kadur
# Processing Record 20 of Set 3 | nalut
# Processing Record 21 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | hobyo
# Processing Record 24 of Set 3 | ginir
# Processing Record 25 of Set 3 | yaounde
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | caravelas
# Processing Record 28 of Set 3 | sabang
# Processing Record 29 of Set 3 | port hawkesbury
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | tagab
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | bolshoye nagatkino
# Processing Record 34 of Set 3 | srivardhan
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | vostok
# Processing Record 38 of Set 3 | mangan
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | poum
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 3 | guerrero negro
# Processing Record 44 of Set 3 | kourou
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | nouadhibou
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | salisbury
# Processing Record 49 of Set 3 | honningsvag
# Processing Record 50 of Set 3 | novobirilyussy
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | dzilam gonzalez
# Processing Record 4 of Set 4 | birnin kebbi
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | oum hadjer
# Processing Record 7 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 4 | coquimbo
# Processing Record 9 of Set 4 | galle
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | barreirinhas
# Processing Record 12 of Set 4 | pacific grove
# Processing Record 13 of Set 4 | logresti
# Processing Record 14 of Set 4 | kaihua
# Processing Record 15 of Set 4 | kuruksay
# City not found. Skipping...
# Processing Record 16 of Set 4 | sinnamary
# Processing Record 17 of Set 4 | hermanus
# Processing Record 18 of Set 4 | kochubey
# Processing Record 19 of Set 4 | goderich
# Processing Record 20 of Set 4 | la ronge
# Processing Record 21 of Set 4 | ibanesti
# Processing Record 22 of Set 4 | mitsamiouli
# Processing Record 23 of Set 4 | bhuvanagiri
# Processing Record 24 of Set 4 | tahoua
# Processing Record 25 of Set 4 | sao jose da coroa grande
# Processing Record 26 of Set 4 | barcarena
# Processing Record 27 of Set 4 | sherlovaya gora
# Processing Record 28 of Set 4 | drabiv
# Processing Record 29 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 4 | palmer
# Processing Record 31 of Set 4 | sechura
# Processing Record 32 of Set 4 | sangar
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | manakara
# Processing Record 36 of Set 4 | borazjan
# Processing Record 37 of Set 4 | pudozh
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | presidencia roque saenz pena
# Processing Record 40 of Set 4 | iranshahr
# Processing Record 41 of Set 4 | amuntai
# Processing Record 42 of Set 4 | khatanga
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | luanda
# Processing Record 45 of Set 4 | tarazona
# Processing Record 46 of Set 4 | nikolskoye
# Processing Record 47 of Set 4 | biak
# Processing Record 48 of Set 4 | saint-louis
# Processing Record 49 of Set 4 | severomuysk
# Processing Record 50 of Set 4 | mount gambier
# Processing Record 1 of Set 5 | diego de almagro
# Processing Record 2 of Set 5 | plock
# Processing Record 3 of Set 5 | saint-augustin
# Processing Record 4 of Set 5 | balabac
# Processing Record 5 of Set 5 | kudahuvadhoo
# Processing Record 6 of Set 5 | ifanadiana
# Processing Record 7 of Set 5 | evensk
# Processing Record 8 of Set 5 | aksu
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | makanya
# Processing Record 11 of Set 5 | matamoros
# Processing Record 12 of Set 5 | alyangula
# Processing Record 13 of Set 5 | westport
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | bud
# Processing Record 18 of Set 5 | los llanos de aridane
# Processing Record 19 of Set 5 | coahuayana
# Processing Record 20 of Set 5 | bulawayo
# Processing Record 21 of Set 5 | sovetsk
# Processing Record 22 of Set 5 | uarini
# Processing Record 23 of Set 5 | mazatlan
# Processing Record 24 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 5 | abu samrah
# Processing Record 26 of Set 5 | katobu
# Processing Record 27 of Set 5 | aswan
# Processing Record 28 of Set 5 | msanga
# Processing Record 29 of Set 5 | huarmey
# Processing Record 30 of Set 5 | ponta do sol
# Processing Record 31 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | bosaso
# Processing Record 34 of Set 5 | krasnoselkup
# Processing Record 35 of Set 5 | onega
# Processing Record 36 of Set 5 | togul
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | vestmanna
# Processing Record 41 of Set 5 | narsaq
# Processing Record 42 of Set 5 | koumac
# Processing Record 43 of Set 5 | sinjhoro
# Processing Record 44 of Set 5 | san borja
# Processing Record 45 of Set 5 | northam
# Processing Record 46 of Set 5 | santa rosa
# Processing Record 47 of Set 5 | buala
# Processing Record 48 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 5 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 50 of Set 5 | kargasok
# Processing Record 1 of Set 6 | maceio
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | kamaishi
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | san quintin
# Processing Record 6 of Set 6 | bullhead city
# Processing Record 7 of Set 6 | manzhouli
# Processing Record 8 of Set 6 | bonnyville
# Processing Record 9 of Set 6 | tuatapere
# Processing Record 10 of Set 6 | wahiawa
# Processing Record 11 of Set 6 | inhambane
# Processing Record 12 of Set 6 | warrnambool
# Processing Record 13 of Set 6 | prince rupert
# Processing Record 14 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 6 | qaanaaq
# Processing Record 16 of Set 6 | xunchang
# Processing Record 17 of Set 6 | kiama
# Processing Record 18 of Set 6 | saint george
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | dubbo
# Processing Record 21 of Set 6 | ust-nera
# Processing Record 22 of Set 6 | grand gaube
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | esperance
# Processing Record 25 of Set 6 | szprotawa
# Processing Record 26 of Set 6 | havre-saint-pierre
# Processing Record 27 of Set 6 | martapura
# Processing Record 28 of Set 6 | funtua
# Processing Record 29 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 30 of Set 6 | miri
# Processing Record 31 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 6 | thouars
# Processing Record 33 of Set 6 | dongsheng
# Processing Record 34 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 6 | loreto
# Processing Record 36 of Set 6 | manhattan
# Processing Record 37 of Set 6 | magaria
# Processing Record 38 of Set 6 | ridgecrest
# Processing Record 39 of Set 6 | montepuez
# Processing Record 40 of Set 6 | pringsewu
# Processing Record 41 of Set 6 | ilulissat
# Processing Record 42 of Set 6 | caetite
# Processing Record 43 of Set 6 | aksarka
# Processing Record 44 of Set 6 | margate
# Processing Record 45 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 6 | eydhafushi
# Processing Record 47 of Set 6 | san nicolas
# Processing Record 48 of Set 6 | yulara
# Processing Record 49 of Set 6 | bodden town
# Processing Record 50 of Set 6 | bitung
# Processing Record 1 of Set 7 | boyolangu
# Processing Record 2 of Set 7 | solok
# Processing Record 3 of Set 7 | kaeo
# Processing Record 4 of Set 7 | lixourion
# Processing Record 5 of Set 7 | brae
# Processing Record 6 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 7 of Set 7 | beringovskiy
# Processing Record 8 of Set 7 | russell
# Processing Record 9 of Set 7 | chanika
# Processing Record 10 of Set 7 | ambon
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | nemuro
# Processing Record 13 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 7 | cabedelo
# Processing Record 15 of Set 7 | amga
# Processing Record 16 of Set 7 | broken hill
# Processing Record 17 of Set 7 | miles city
# Processing Record 18 of Set 7 | key west
# Processing Record 19 of Set 7 | meulaboh
# Processing Record 20 of Set 7 | salalah
# Processing Record 21 of Set 7 | sovetskiy
# Processing Record 22 of Set 7 | saint-pierre
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | khani
# Processing Record 25 of Set 7 | hovd
# Processing Record 26 of Set 7 | fredericksburg
# Processing Record 27 of Set 7 | luau
# Processing Record 28 of Set 7 | gasa
# Processing Record 29 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 7 | cockburn town
# Processing Record 31 of Set 7 | wichian buri
# Processing Record 32 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 7 | the valley
# Processing Record 34 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | saskylakh
# Processing Record 37 of Set 7 | codajas
# Processing Record 38 of Set 7 | seymchan
# Processing Record 39 of Set 7 | uray
# Processing Record 40 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | ongandjera
# Processing Record 43 of Set 7 | ryotsu
# Processing Record 44 of Set 7 | lahaina
# Processing Record 45 of Set 7 | clarence town
# Processing Record 46 of Set 7 | egvekinot
# Processing Record 47 of Set 7 | urfa
# City not found. Skipping...
# Processing Record 48 of Set 7 | nantucket
# Processing Record 49 of Set 7 | pontalina
# Processing Record 50 of Set 7 | aripuana
# Processing Record 1 of Set 8 | midleton
# Processing Record 2 of Set 8 | cherskiy
# Processing Record 3 of Set 8 | weihai
# Processing Record 4 of Set 8 | chimoio
# Processing Record 5 of Set 8 | galveston
# Processing Record 6 of Set 8 | bowen
# Processing Record 7 of Set 8 | labuhan
# Processing Record 8 of Set 8 | kamphaeng phet
# Processing Record 9 of Set 8 | sawakin
# Processing Record 10 of Set 8 | tarko-sale
# Processing Record 11 of Set 8 | ozernovskiy
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | igarka
# Processing Record 15 of Set 8 | kunya
# Processing Record 16 of Set 8 | vicuna
# Processing Record 17 of Set 8 | chengde
# Processing Record 18 of Set 8 | vestmannaeyjar
# Processing Record 19 of Set 8 | anadyr
# Processing Record 20 of Set 8 | luena
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | vao
# Processing Record 23 of Set 8 | sarai naurang
# Processing Record 24 of Set 8 | bansgaon
# Processing Record 25 of Set 8 | la reforma
# Processing Record 26 of Set 8 | kapuskasing
# Processing Record 27 of Set 8 | williston
# Processing Record 28 of Set 8 | bengkulu
# Processing Record 29 of Set 8 | pokhara
# Processing Record 30 of Set 8 | rawson
# Processing Record 31 of Set 8 | dabat
# Processing Record 32 of Set 8 | bonfim
# Processing Record 33 of Set 8 | moranbah
# Processing Record 34 of Set 8 | nishihara
# Processing Record 35 of Set 8 | norman wells
# Processing Record 36 of Set 8 | fukue
# Processing Record 37 of Set 8 | chattanooga
# Processing Record 38 of Set 8 | provideniya
# Processing Record 39 of Set 8 | balaipungut
# Processing Record 40 of Set 8 | eatonton
# Processing Record 41 of Set 8 | mareeba
# Processing Record 42 of Set 8 | bambous virieux
# Processing Record 43 of Set 8 | chapais
# Processing Record 44 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 45 of Set 8 | lethbridge
# Processing Record 46 of Set 8 | rundu
# Processing Record 47 of Set 8 | novouralsk
# Processing Record 48 of Set 8 | pekan
# Processing Record 49 of Set 8 | homer
# Processing Record 50 of Set 8 | maragogi
# Processing Record 1 of Set 9 | bandar-e lengeh
# Processing Record 2 of Set 9 | karatuzskoye
# Processing Record 3 of Set 9 | pingliang
# Processing Record 4 of Set 9 | necochea
# Processing Record 5 of Set 9 | ternate
# Processing Record 6 of Set 9 | ranau
# Processing Record 7 of Set 9 | seda
# Processing Record 8 of Set 9 | moron
# Processing Record 9 of Set 9 | paamiut
# Processing Record 10 of Set 9 | kloulklubed
# Processing Record 11 of Set 9 | chunskiy
# Processing Record 12 of Set 9 | parry sound
# Processing Record 13 of Set 9 | porto nacional
# Processing Record 14 of Set 9 | pirgos
# Processing Record 15 of Set 9 | husavik
# Processing Record 16 of Set 9 | okhotsk
# Processing Record 17 of Set 9 | roanoke
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | opelousas
# Processing Record 20 of Set 9 | shingu
# Processing Record 21 of Set 9 | kumano
# Processing Record 22 of Set 9 | pundaguitan
# Processing Record 23 of Set 9 | asau
# Processing Record 24 of Set 9 | derbent
# Processing Record 25 of Set 9 | sivaki
# Processing Record 26 of Set 9 | haines junction
# Processing Record 27 of Set 9 | svetlaya
# Processing Record 28 of Set 9 | sao gabriel da cachoeira
# Processing Record 29 of Set 9 | kathu
# Processing Record 30 of Set 9 | eyl
# Processing Record 31 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | zhezkazgan
# Processing Record 33 of Set 9 | nome
# Processing Record 34 of Set 9 | monsenhor gil
# Processing Record 35 of Set 9 | abu dhabi
# Processing Record 36 of Set 9 | orlovskiy
# Processing Record 37 of Set 9 | kulhudhuffushi
# Processing Record 38 of Set 9 | tomatlan
# Processing Record 39 of Set 9 | kayerkan
# Processing Record 40 of Set 9 | muhos
# Processing Record 41 of Set 9 | tual
# Processing Record 42 of Set 9 | gornyak
# Processing Record 43 of Set 9 | terra santa
# Processing Record 44 of Set 9 | kongolo
# Processing Record 45 of Set 9 | bandarbeyla
# Processing Record 46 of Set 9 | sale
# Processing Record 47 of Set 9 | kampot
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | sibirtsevo
# City not found. Skipping...
# Processing Record 50 of Set 9 | harper
# Processing Record 1 of Set 10 | corner brook
# Processing Record 2 of Set 10 | pulandian
# Processing Record 3 of Set 10 | west odessa
# Processing Record 4 of Set 10 | faxinal
# Processing Record 5 of Set 10 | veroia
# Processing Record 6 of Set 10 | kholmogory
# Processing Record 7 of Set 10 | isiro
# Processing Record 8 of Set 10 | iskateley
# Processing Record 9 of Set 10 | faya
# Processing Record 10 of Set 10 | olafsvik
# Processing Record 11 of Set 10 | lompoc
# Processing Record 12 of Set 10 | talnakh
# Processing Record 13 of Set 10 | palembang
# Processing Record 14 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 15 of Set 10 | jaciara
# Processing Record 16 of Set 10 | zaragoza
# Processing Record 17 of Set 10 | palana
# Processing Record 18 of Set 10 | kasongo-lunda
# Processing Record 19 of Set 10 | nenjiang
# Processing Record 20 of Set 10 | lagoa
# Processing Record 21 of Set 10 | isangel
# Processing Record 22 of Set 10 | ca mau
# Processing Record 23 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 10 | annau
# Processing Record 25 of Set 10 | chaman
# Processing Record 26 of Set 10 | paka
# Processing Record 27 of Set 10 | mana
# Processing Record 28 of Set 10 | brigantine
# Processing Record 29 of Set 10 | klaksvik
# Processing Record 30 of Set 10 | rosetta
# Processing Record 31 of Set 10 | namibe
# Processing Record 32 of Set 10 | khislavichi
# Processing Record 33 of Set 10 | ugoofaaru
# Processing Record 34 of Set 10 | puro
# Processing Record 35 of Set 10 | pleasanton
# Processing Record 36 of Set 10 | bacungan
# Processing Record 37 of Set 10 | youkounkoun
# Processing Record 38 of Set 10 | sola
# Processing Record 39 of Set 10 | alenquer
# Processing Record 40 of Set 10 | powell
# Processing Record 41 of Set 10 | pacifica
# Processing Record 42 of Set 10 | bukene
# Processing Record 43 of Set 10 | noyabrsk
# Processing Record 44 of Set 10 | bilma
# Processing Record 45 of Set 10 | manokwari
# Processing Record 46 of Set 10 | narasannapeta
# Processing Record 47 of Set 10 | saint-francois
# Processing Record 48 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 10 | conakry
# Processing Record 50 of Set 10 | quatre cocos
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | sunland park
# Processing Record 3 of Set 11 | bonavista
# Processing Record 4 of Set 11 | aranos
# Processing Record 5 of Set 11 | zyryanka
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | salinopolis
# Processing Record 8 of Set 11 | kavaratti
# Processing Record 9 of Set 11 | kavieng
# Processing Record 10 of Set 11 | artigas
# Processing Record 11 of Set 11 | hokitika
# Processing Record 12 of Set 11 | ayan
# Processing Record 13 of Set 11 | taoudenni
# Processing Record 14 of Set 11 | oskemen
# Processing Record 15 of Set 11 | haradok
# Processing Record 16 of Set 11 | tiksi
# Processing Record 17 of Set 11 | college
# Processing Record 18 of Set 11 | clyde river
# Processing Record 19 of Set 11 | sambava
# Processing Record 20 of Set 11 | consett
# Processing Record 21 of Set 11 | gillette
# Processing Record 22 of Set 11 | puerto baquerizo moreno
# Processing Record 23 of Set 11 | el torno
# Processing Record 24 of Set 11 | reforma
# Processing Record 25 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 26 of Set 11 | guinguineo
# Processing Record 27 of Set 11 | aklavik
# Processing Record 28 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 29 of Set 11 | ekangala
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | takoradi
# Processing Record 32 of Set 11 | yanam
# Processing Record 33 of Set 11 | pombas
# Processing Record 34 of Set 11 | domoni
# Processing Record 35 of Set 11 | lokosovo
# Processing Record 36 of Set 11 | neiafu
# Processing Record 37 of Set 11 | riyadh
# Processing Record 38 of Set 11 | broome
# Processing Record 39 of Set 11 | vozhega
# Processing Record 40 of Set 11 | kontagora
# Processing Record 41 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 11 | arkhipo-osipovka
# Processing Record 43 of Set 11 | callaway
# Processing Record 44 of Set 11 | new plymouth
# Processing Record 45 of Set 11 | swan hill
# Processing Record 46 of Set 11 | dunedin
# Processing Record 47 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 11 | mantua
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 50 of Set 11 | san ramon
# Processing Record 1 of Set 12 | markova
# Processing Record 2 of Set 12 | mariental
# Processing Record 3 of Set 12 | bathsheba
# Processing Record 4 of Set 12 | clermont
# Processing Record 5 of Set 12 | thinadhoo
# Processing Record 6 of Set 12 | bambanglipuro
# Processing Record 7 of Set 12 | hambantota
# Processing Record 8 of Set 12 | rocha
# Processing Record 9 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 10 of Set 12 | capreol
# Processing Record 11 of Set 12 | baglung
# Processing Record 12 of Set 12 | puerto del rosario
# Processing Record 13 of Set 12 | viedma
# Processing Record 14 of Set 12 | maldonado
# Processing Record 15 of Set 12 | codrington
# Processing Record 16 of Set 12 | tabuk
# Processing Record 17 of Set 12 | te anau
# Processing Record 18 of Set 12 | temecula
# Processing Record 19 of Set 12 | emerald
# Processing Record 20 of Set 12 | tigil
# Processing Record 21 of Set 12 | klyuchi
# Processing Record 22 of Set 12 | watsa
# Processing Record 23 of Set 12 | susangerd
# City not found. Skipping...
# Processing Record 24 of Set 12 | praia
# Processing Record 25 of Set 12 | abeche
# Processing Record 26 of Set 12 | jacareacanga
# Processing Record 27 of Set 12 | san ramon de la nueva oran
# Processing Record 28 of Set 12 | omboue
# Processing Record 29 of Set 12 | moussoro
# Processing Record 30 of Set 12 | mwinilunga
# Processing Record 31 of Set 12 | odweyne
# Processing Record 32 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 12 | maumere
# Processing Record 34 of Set 12 | bograd
# Processing Record 35 of Set 12 | antofagasta
# Processing Record 36 of Set 12 | vardo
# Processing Record 37 of Set 12 | nipawin
# Processing Record 38 of Set 12 | lorengau
# Processing Record 39 of Set 12 | sherpur
# Processing Record 40 of Set 12 | kirakira
# Processing Record 41 of Set 12 | bhuj
# Processing Record 42 of Set 12 | santa maria da vitoria
# Processing Record 43 of Set 12 | kununurra
# Processing Record 44 of Set 12 | vuktyl
# Processing Record 45 of Set 12 | champerico
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | cottbus
# Processing Record 48 of Set 12 | torbay
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | coihaique
# Processing Record 1 of Set 13 | bako
# Processing Record 2 of Set 13 | daru
# Processing Record 3 of Set 13 | verkhnyaya toyma
# Processing Record 4 of Set 13 | antalaha
# Processing Record 5 of Set 13 | moorhead
# Processing Record 6 of Set 13 | birao
# Processing Record 7 of Set 13 | ballina
# Processing Record 8 of Set 13 | pakwach
# City not found. Skipping...
# Processing Record 9 of Set 13 | shu
# Processing Record 10 of Set 13 | kahului
# Processing Record 11 of Set 13 | skanevik
# City not found. Skipping...
# Processing Record 12 of Set 13 | san carlos del zulia
# Processing Record 13 of Set 13 | tazovskiy
# Processing Record 14 of Set 13 | dana point
# Processing Record 15 of Set 13 | tomohon
# Processing Record 16 of Set 13 | yingcheng
# Processing Record 17 of Set 13 | biltine
# Processing Record 18 of Set 13 | comodoro rivadavia
# Processing Record 19 of Set 13 | marsabit
# Processing Record 20 of Set 13 | lyaskelya
# Processing Record 21 of Set 13 | kamenka
# Processing Record 22 of Set 13 | telimele
# Processing Record 23 of Set 13 | flinders
# Processing Record 24 of Set 13 | bilibino
# Processing Record 25 of Set 13 | eirunepe
# Processing Record 26 of Set 13 | atar
# Processing Record 27 of Set 13 | eslov
# Processing Record 28 of Set 13 | colares
# Processing Record 29 of Set 13 | troitsko-pechorsk
# Processing Record 30 of Set 13 | yenangyaung
# Processing Record 31 of Set 13 | krutinka
# Processing Record 32 of Set 13 | geraldton
# Processing Record 33 of Set 13 | calvinia
# Processing Record 34 of Set 13 | burnie
# Processing Record 35 of Set 13 | mayumba
# Processing Record 36 of Set 13 | sayyan
# Processing Record 37 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 13 | orthez
# Processing Record 39 of Set 13 | ixtapa
# Processing Record 40 of Set 13 | morecambe
# Processing Record 41 of Set 13 | novosemeykino
# Processing Record 42 of Set 13 | kabelvag
# Processing Record 43 of Set 13 | arroio grande
# Processing Record 44 of Set 13 | hami
# Processing Record 45 of Set 13 | sabla
# Processing Record 46 of Set 13 | kushiro
# Processing Record 47 of Set 13 | bull savanna
# Processing Record 48 of Set 13 | iquique
# Processing Record 49 of Set 13 | yelizovo
# Processing Record 50 of Set 13 | mindelo
# Processing Record 1 of Set 14 | banda aceh
# Processing Record 2 of Set 14 | bubaque
# Processing Record 3 of Set 14 | isla vista
# Processing Record 4 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 5 of Set 14 | batagay
# Processing Record 6 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 14 | ajdabiya
# Processing Record 8 of Set 14 | athabasca
# Processing Record 9 of Set 14 | atambua
# Processing Record 10 of Set 14 | acapulco
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | kendari
# Processing Record 13 of Set 14 | tadine
# Processing Record 14 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 14 | shahdadkot
# Processing Record 16 of Set 14 | baruun-urt
# Processing Record 17 of Set 14 | manado
# Processing Record 18 of Set 14 | batagay-alyta
# Processing Record 19 of Set 14 | cabinda
# Processing Record 20 of Set 14 | dawei
# Processing Record 21 of Set 14 | nabul
# City not found. Skipping...
# Processing Record 22 of Set 14 | idil
# Processing Record 23 of Set 14 | krasnyy chikoy
# Processing Record 24 of Set 14 | camacupa
# Processing Record 25 of Set 14 | mount isa
# Processing Record 26 of Set 14 | sirajganj
# Processing Record 27 of Set 14 | langsa
# Processing Record 28 of Set 14 | grindavik
# Processing Record 29 of Set 14 | makhinjauri
# Processing Record 30 of Set 14 | gravdal
# Processing Record 31 of Set 14 | melo
# Processing Record 32 of Set 14 | raipur
# Processing Record 33 of Set 14 | mabama
# Processing Record 34 of Set 14 | trincomalee
# Processing Record 35 of Set 14 | mayo
# Processing Record 36 of Set 14 | point pleasant
# Processing Record 37 of Set 14 | port hedland
# Processing Record 38 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 14 | kalmunai
# Processing Record 40 of Set 14 | san carlos de bariloche
# Processing Record 41 of Set 14 | lhokseumawe
# Processing Record 42 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 14 | sabha
# Processing Record 44 of Set 14 | bontang
# Processing Record 45 of Set 14 | alekseyevsk
# Processing Record 46 of Set 14 | qaqortoq
# Processing Record 47 of Set 14 | ust-kuyga
# Processing Record 48 of Set 14 | vodnyy
# Processing Record 49 of Set 14 | khandyga
# Processing Record 50 of Set 14 | zatoka
# Processing Record 1 of Set 15 | laurel
# Processing Record 2 of Set 15 | namatanai
# Processing Record 3 of Set 15 | lazaro cardenas
# Processing Record 4 of Set 15 | methoni
# Processing Record 5 of Set 15 | nova londrina
# Processing Record 6 of Set 15 | belmonte
# Processing Record 7 of Set 15 | puerto leguizamo
# Processing Record 8 of Set 15 | bac lieu
# Processing Record 9 of Set 15 | port keats
# Processing Record 10 of Set 15 | abbeville
# Processing Record 11 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 15 | beira
# Processing Record 13 of Set 15 | celestun
# Processing Record 14 of Set 15 | clovis
# Processing Record 15 of Set 15 | gurlan
# Processing Record 16 of Set 15 | ketchikan
# Processing Record 17 of Set 15 | kieta
# Processing Record 18 of Set 15 | takanabe
# Processing Record 19 of Set 15 | ishigaki
# Processing Record 20 of Set 15 | saint-hyacinthe
# Processing Record 21 of Set 15 | shelburne
# Processing Record 22 of Set 15 | ottumwa
# Processing Record 23 of Set 15 | imbituba
# Processing Record 24 of Set 15 | glace bay
# Processing Record 25 of Set 15 | tabou
# Processing Record 26 of Set 15 | uige
# Processing Record 27 of Set 15 | kutum
# Processing Record 28 of Set 15 | goundam
# Processing Record 29 of Set 15 | concepcion del uruguay
# Processing Record 30 of Set 15 | porto walter
# Processing Record 31 of Set 15 | san andres
# Processing Record 32 of Set 15 | auki
# Processing Record 33 of Set 15 | tineo
# Processing Record 34 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 15 | matay
# Processing Record 36 of Set 15 | dicabisagan
# Processing Record 37 of Set 15 | angoche
# Processing Record 38 of Set 15 | estacion coahuila
# Processing Record 39 of Set 15 | agva
# City not found. Skipping...
# Processing Record 40 of Set 15 | sfantu gheorghe
# Processing Record 41 of Set 15 | paraiso
# Processing Record 42 of Set 15 | beloha
# Processing Record 43 of Set 15 | akyab
# Processing Record 44 of Set 15 | lishui
# Processing Record 45 of Set 15 | tessalit
# Processing Record 46 of Set 15 | kimbe
# Processing Record 47 of Set 15 | murray bridge
# Processing Record 48 of Set 15 | dingle
# Processing Record 49 of Set 15 | boa vista
# Processing Record 50 of Set 15 | belaya gora
# Processing Record 1 of Set 16 | mizdah
# Processing Record 2 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 3 of Set 16 | bethanien
# Processing Record 4 of Set 16 | road town
# Processing Record 5 of Set 16 | erenhot
# Processing Record 6 of Set 16 | buraydah
# Processing Record 7 of Set 16 | kidal
# Processing Record 8 of Set 16 | anloga
# Processing Record 9 of Set 16 | panzhihua
# Processing Record 10 of Set 16 | spas-demensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Hilo  19.7297 -155.0900     83.28        82          20        4.61
# 1    Mahebourg -20.4081   57.7000     76.24        78          40        4.61
# 2       Bonthe   7.5264  -12.5050     79.47        79          21        5.97
# 3  Tuktoyaktuk  69.4541 -133.0374     -0.40        85         100        8.05
# 4        Kapaa  22.0752 -159.3190     80.92        85           0        9.22
# 5    Abu Kamal  34.4506   40.9171     61.32        67          71        5.14
# 6   Butaritari   3.0707  172.7902     81.10        77          18       13.18
# 7   Nanortalik  60.1432  -45.2371     29.98        83         100       18.66
# 8      Ahipara -35.1667  173.1667     61.25        68          99       15.93
# 9      Ambanja -13.6833   48.4500     73.81        93          36        0.67
#
#   Country                 Date City Weather Description
# 0      US  2022-11-30 19:29:38               few clouds
# 1      MU  2022-11-30 19:31:46         scattered clouds
# 2      SL  2022-11-30 19:31:51               few clouds
# 3      CA  2022-11-30 19:31:51               light snow
# 4      US  2022-11-30 19:31:52                clear sky
# 5      SY  2022-11-30 19:31:52            broken clouds
# 6      KI  2022-11-30 19:31:52               few clouds
# 7      GL  2022-11-30 19:31:53          overcast clouds
# 8      NZ  2022-11-30 19:31:53          overcast clouds
# 9      MG  2022-11-30 19:31:54            moderate rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'City Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "City Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hilo      US  19.7297 -155.0900     83.28        82          20
# 1    Mahebourg      MU -20.4081   57.7000     76.24        78          40
# 2       Bonthe      SL   7.5264  -12.5050     79.47        79          21
# 3  Tuktoyaktuk      CA  69.4541 -133.0374     -0.40        85         100
# 4        Kapaa      US  22.0752 -159.3190     80.92        85           0
# 5    Abu Kamal      SY  34.4506   40.9171     61.32        67          71
# 6   Butaritari      KI   3.0707  172.7902     81.10        77          18
# 7   Nanortalik      GL  60.1432  -45.2371     29.98        83         100
# 8      Ahipara      NZ -35.1667  173.1667     61.25        68          99
# 9      Ambanja      MG -13.6833   48.4500     73.81        93          36
#
#    Wind Speed City Weather Description
# 0        4.61               few clouds
# 1        4.61         scattered clouds
# 2        5.97               few clouds
# 3        8.05               light snow
# 4        9.22                clear sky
# 5        5.14            broken clouds
# 6       13.18               few clouds
# 7       18.66          overcast clouds
# 8       15.93          overcast clouds
# 9        0.67            moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                         object
# Country                      object
# Lat                         float64
# Lng                         float64
# Max Temp                    float64
# Humidity                      int64
# Cloudiness                    int64
# Wind Speed                  float64
# City Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
